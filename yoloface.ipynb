# %%
from datetime import datetime

a = str(datetime.now())
a[: 19]
# Out:
# '2019-11-21 22:58:21'

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# !cd drive
# !ls
# !python '/content/drive/My Drive/yoloface-master/yoloface.py' --video '/content/drive/My Drive/sample (3)/video.h264'  --output-dir '/content/drive/My Drive/outputs/'
#
# Out:
# ----- info -----
# [i] The config file:  /content/drive/My Drive/yoloface-master/cfg/yolov3-face.cfg
# [i] The weights of model file:  /content/drive/My Drive/yoloface-master/model-weights/yolov3-wider_16000.weights
# [i] Path to image file:
# [i] Path to video file:  /content/drive/My Drive/sample (3)/video.h264
# ###########################################################
#
# ==> Skipping create the /content/drive/My Drive/outputs/ directory...
# 2019-11-21 23:21:04.238262
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:05.819055
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:07.420264
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:08.981578
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:10.528228
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:12.083212
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:13.617293
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:15.180885
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:16.721313
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:18.304254
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:19.855505
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:21.407691
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:22.979339
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:24.544252
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:26.099200
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:27.668550
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:29.228640
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:30.788434
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:32.372613
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:33.909506
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:35.463450
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:37.018154
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:38.597949
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:40.150438
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:41.704148
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:43.262012
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:44.798114
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:46.342587
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:47.893360
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:49.439382
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:50.993537
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:52.551053
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:54.109198
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:55.658341
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:57.213767
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:21:58.768259
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:00.327689
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:01.881639
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:03.441138
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:04.986530
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:06.566256
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:08.127320
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:09.679850
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:11.229249
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:12.788258
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:14.324230
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:15.894459
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:17.440519
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:19.007210
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:20.550931
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:22.125936
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:23.679070
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:25.225036
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:26.778235
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:28.338983
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:29.889419
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:31.484427
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:33.039406
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:34.555515
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:36.049517
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:37.584856
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:39.077102
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:40.587345
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:42.094389
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:43.601707
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:45.081433
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:46.568803
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:48.080408
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:49.577431
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:51.067814
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:52.565506
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:54.076729
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:55.569866
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:57.054410
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:22:58.545652
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:00.069431
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:01.561970
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:03.053828
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:04.555257
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:06.025396
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:07.532494
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:09.012719
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:10.498851
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:11.979323
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:13.456268
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:14.951515
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:16.443718
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:17.945324
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:19.454841
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:20.970093
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:22.459667
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:23.941434
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:25.442493
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:26.927049
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:28.417250
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:29.905049
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:31.399213
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:32.882973
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:34.377847
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:35.860470
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:37.370255
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:38.848359
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:40.348796
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:41.841019
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:43.327142
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:44.810982
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:46.305939
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:47.806462
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:49.301499
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:50.805120
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:52.314941
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:53.822353
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:55.317742
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:56.815369
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:58.325328
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:23:59.824153
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:01.341699
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:02.825799
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:04.337169
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:05.841199
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:07.354548
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:08.833107
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:10.329564
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:11.800996
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:13.306131
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:14.789735
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:16.285188
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:17.799670
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:19.289603
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:20.796272
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:22.285087
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:23.782689
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:25.269263
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:26.768591
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:28.274923
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:29.769019
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:31.274460
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:32.774564
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:34.278731
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:35.759501
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:37.266712
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:38.783040
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# 2019-11-21 23:24:40.269792
# [i] ==> # detected faces: 0
# ############################################################
# passed :  [0]
# [i] ==> Done processing!!!
# [i] ==> Output file is stored at /content/drive/My Drive/outputs/video._yoloface.avi
# ==> All done!
# ***********************************************************

# %%
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# *******************************************************************
#
# Author : Thanh Nguyen, 2018
# Email  : sthanhng@gmail.com
# Github : https://github.com/sthanhng
#
# BAP, AI Team
# Face detection using the YOLOv3 algorithm
#
# Description : yoloface.py
# The main code of the Face detection using the YOLOv3 algorithm
#
# *******************************************************************

# Usage example:  python yoloface.py --image samples/outside_000001.jpg \
#                                    --output-dir outputs/
#                 python yoloface.py --video samples/subway.mp4 \
#                                    --output-dir outputs/
#                 python yoloface.py --src 1 --output-dir outputs/


import argparse
import sys
import os
import numpy as np

from utils import *



#####################################################################
parser = argparse.ArgumentParser()
parser.add_argument('--model-cfg', type=str, default='./cfg/yolov3-face.cfg',
                    help='path to config file')
parser.add_argument('--model-weights', type=str,
                    default='./model-weights/yolov3-wider_16000.weights',
                    # './model-weights/yolov3-wider_16000.weights' './model-weights/get_models.sh'
                    # /content/drive/My Drive/yoloface-master/model-weights/yolov3-wider_16000.weights
                    help='path to weights of model')
parser.add_argument('--image', type=str, default='',
                    help='path to image file')
parser.add_argument('--video', type=str, default='',
                    help='path to video file')
parser.add_argument('--src', type=int, default=0,
                    help='source of the camera')
parser.add_argument('--output-dir', type=str, default='outputs/',
                    help='path to the output directory')
args = parser.parse_args()

#####################################################################
# print the arguments
print('----- info -----')
print('[i] The config file: ', args.model_cfg)
print('[i] The weights of model file: ', args.model_weights)
print('[i] Path to image file: ', args.image)
print('[i] Path to video file: ', args.video)
print('###########################################################\n')

# check outputs directory
if not os.path.exists(args.output_dir):
    print('==> Creating the {} directory...'.format(args.output_dir))
    os.makedirs(args.output_dir)
else:
    print('==> Skipping create the {} directory...'.format(args.output_dir))

# Give the configuration and weight files for the model and load the network
# using them.
net = cv2.dnn.readNetFromDarknet(args.model_cfg, args.model_weights)
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)


def _main():
    wind_name = 'face detection using YOLOv3'
    cv2.namedWindow(wind_name, cv2.WINDOW_NORMAL)

    output_file = ''

    if args.image:
        if not os.path.isfile(args.image):
            print("[!] ==> Input image file {} doesn't exist".format(args.image))
            sys.exit(1)
        cap = cv2.VideoCapture(args.image)
        output_file = args.image[:-4].rsplit('/')[-1] + '_yoloface.jpg'
    elif args.video:
        if not os.path.isfile(args.video):
            print("[!] ==> Input video file {} doesn't exist".format(args.video))
            sys.exit(1)
        cap = cv2.VideoCapture(args.video)
        output_file = args.video[:-4].rsplit('/')[-1] + '_yoloface.avi'
    else:
        # Get data from the camera
        cap = cv2.VideoCapture(args.src)

    # Get the video writer initialized to save the output video
    if not args.image:
        video_writer = cv2.VideoWriter(os.path.join(args.output_dir, output_file),
                                       cv2.VideoWriter_fourcc('M', 'J', 'P', 'G'),
                                       cap.get(cv2.CAP_PROP_FPS), (
                                           round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
                                           round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

    
    # jinoo
    centerPoints = []
    passed = [0]

    while True:

        has_frame, frame = cap.read()

        # Stop the program if reached end of video
        if not has_frame:
            print('[i] ==> Done processing!!!')
            print('[i] ==> Output file is stored at', os.path.join(args.output_dir, output_file))
            cv2.waitKey(1000)
            break

        # Create a 4D blob from a frame.
        blob = cv2.dnn.blobFromImage(frame, 1 / 255, (IMG_WIDTH, IMG_HEIGHT),
                                     [0, 0, 0], 1, crop=False)

        # Sets the input to the network
        net.setInput(blob)

        # Runs the forward pass to get output of the output layers
        outs = net.forward(get_outputs_names(net))

        # Remove the bounding boxes with low confidence
        faces = post_process(frame, outs, CONF_THRESHOLD, NMS_THRESHOLD, centerPoints, passed)
        print('[i] ==> # detected faces: {}'.format(len(faces)))
        print('#' * 60)

        # initialize the set of information we'll displaying on the frame
        info = [
            ('number of faces detected', '{}'.format(len(faces)))
        ]
        cv2.line(frame, (1000,0), (1000,600), COLOR_GREEN, 2)
        for (i, (txt, val)) in enumerate(info):
            text = '{}: {}'.format(txt, val)
            cv2.putText(frame, text, (10, (i * 20) + 20),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, COLOR_RED, 2)
            cv2.putText(frame, "Passed passenger : " + str(passed[len(passed)-1]), (10, 100), cv2.FONT_HERSHEY_SIMPLEX, 1.5 ,COLOR_GREEN, 2)

        print("passed : ", passed)

        # Save the output video to file
        if args.image:
            cv2.imwrite(os.path.join(args.output_dir, output_file), frame.astype(np.uint8))
        else:
            video_writer.write(frame.astype(np.uint8))

        cv2.imshow(wind_name, frame)

        key = cv2.waitKey(1)
        if key == 27 or key == ord('q'):
            print('[i] ==> Interrupted by user!')
            break

    cap.release()
    cv2.destroyAllWindows()

    print('==> All done!')
    print('***********************************************************')


if __name__ == '__main__':
    _main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-601f68c3c7be> in <module>()
#       6 import numpy as np
#       7
# ----> 8 from utils import *
#       9
#      10
#
# ModuleNotFoundError: No module named 'utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
